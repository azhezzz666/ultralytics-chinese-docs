# %% [markdown]
# <div align="center">
#   <a href="https://ultralytics.com/yolo" target="_blank">
#     <img width="1024" src="https://raw.githubusercontent.com/ultralytics/assets/main/yolov8/banner-yolov8.png">
#   </a>
#
#   [中文](https://docs.ultralytics.com/zh/) | [한국어](https://docs.ultralytics.com/ko/) | [日本語](https://docs.ultralytics.com/ja/) | [Русский](https://docs.ultralytics.com/ru/) | [Deutsch](https://docs.ultralytics.com/de/) | [Français](https://docs.ultralytics.com/fr/) | [Español](https://docs.ultralytics.com/es/) | [Português](https://docs.ultralytics.com/pt/) | [Türkçe](https://docs.ultralytics.com/tr/) | [Tiếng Việt](https://docs.ultralytics.com/vi/) | [العربية](https://docs.ultralytics.com/ar/)
#
#   <a href="https://github.com/ultralytics/ultralytics/actions/workflows/ci.yml"><img src="https://github.com/ultralytics/ultralytics/actions/workflows/ci.yml/badge.svg" alt="Ultralytics CI"></a>
#   <a href="https://console.paperspace.com/github/ultralytics/ultralytics"><img src="https://assets.paperspace.io/img/gradient-badge.svg" alt="在 Gradient 上运行"/></a>
#   <a href="https://colab.research.google.com/github/ultralytics/ultralytics/blob/main/examples/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="在 Colab 中打开"></a>
#   <a href="https://www.kaggle.com/models/ultralytics/yolo11"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="在 Kaggle 中打开"></a>
#
#   <a href="https://ultralytics.com/discord"><img alt="Discord" src="https://img.shields.io/discord/1089800235347353640?logo=discord&logoColor=white&label=Discord&color=blue"></a>
#   <a href="https://community.ultralytics.com"><img alt="Ultralytics 论坛" src="https://img.shields.io/discourse/users?server=https%3A%2F%2Fcommunity.ultralytics.com&logo=discourse&label=Forums&color=blue"></a>
#   <a href="https://reddit.com/r/ultralytics"><img alt="Ultralytics Reddit" src="https://img.shields.io/reddit/subreddit-subscribers/ultralytics?style=flat&logo=reddit&logoColor=white&label=Reddit&color=blue"></a>
# </div>
#
# 这个 **Ultralytics Colab 笔记本** 是开始使用 [YOLO 模型](https://www.ultralytics.com/yolo) 的最简单方式——无需安装。由 YOLO 的创建者 [Ultralytics](https://www.ultralytics.com/) 构建，本笔记本将引导你直接在浏览器中运行**最先进的**模型。
#
# Ultralytics 模型不断更新以提高性能和灵活性。它们**快速**、**准确**且**易于使用**，在[目标检测](https://docs.ultralytics.com/tasks/detect/)、[跟踪](https://docs.ultralytics.com/modes/track/)、[实例分割](https://docs.ultralytics.com/tasks/segment/)、[图像分类](https://docs.ultralytics.com/tasks/classify/)和[姿态估计](https://docs.ultralytics.com/tasks/pose/)方面表现出色。
#
# 在 [Ultralytics 文档](https://docs.ultralytics.com/) 中查找详细文档。通过 [GitHub Issues](https://github.com/ultralytics/ultralytics/issues/new/choose) 获取支持。在 [Discord](https://discord.com/invite/ultralytics)、[Reddit](https://www.reddit.com/r/ultralytics/) 和 [Ultralytics 社区论坛](https://community.ultralytics.com/) 上参与讨论！
#
# 在 [Ultralytics 许可](https://www.ultralytics.com/license) 申请商业使用的企业许可证。
#
# <br>
# <div>
#   <a href="https://www.youtube.com/watch?v=ZN3nRZT7b24" target="_blank">
#     <img src="https://img.youtube.com/vi/ZN3nRZT7b24/maxresdefault.jpg" alt="Ultralytics 视频" width="640" style="border-radius: 10px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);">
#   </a>
#
#   <p style="font-size: 16px; font-family: Arial, sans-serif; color: #555;">
#     <strong>观看：</strong> 如何使用 Google Colab 笔记本在自定义数据集上训练
#     <a href="https://github.com/ultralytics/ultralytics">Ultralytics</a>
#     <a href="https://docs.ultralytics.com/models/yolo11/">YOLO11</a> 模型 🚀
#   </p>
# </div>

# %% [markdown]
# # 设置
#
# 使用 pip 安装 `ultralytics` 和[依赖项](https://github.com/ultralytics/ultralytics/blob/main/pyproject.toml)，并检查软件和硬件。
#
# [![PyPI - Version](https://img.shields.io/pypi/v/ultralytics?logo=pypi&logoColor=white)](https://pypi.org/project/ultralytics/) [![Downloads](https://static.pepy.tech/badge/ultralytics)](https://clickpy.clickhouse.com/dashboard/ultralytics) [![PyPI - Python Version](https://img.shields.io/pypi/pyversions/ultralytics?logo=python&logoColor=gold)](https://pypi.org/project/ultralytics/)

# %%
# !uv pip install ultralytics
import ultralytics
ultralytics.checks()

# %% [markdown]
# # 1. 预测
#
# YOLO11 可以直接在命令行界面（CLI）中使用 `yolo` 命令执行各种任务和模式，并接受额外参数，如 `imgsz=640`。在 [YOLO11 预测文档](https://docs.ultralytics.com/modes/train/) 中查看可用 `yolo` [参数](https://docs.ultralytics.com/usage/cfg/) 的完整列表和其他详细信息。

# %%
# 使用 YOLO11n 对图像进行推理
# !yolo predict model=yolo11n.pt source='https://ultralytics.com/images/zidane.jpg'

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/212889447-69e5bdf1-5800-4e29-835e-2ed2336dede2.jpg" width="600">

# %% [markdown]
# # 2. 验证
# 在 [COCO](https://docs.ultralytics.com/datasets/detect/coco/) 数据集的 `val` 或 `test` 分割上验证模型的准确性。最新的 YOLO11 [模型](https://github.com/ultralytics/ultralytics#models) 会在首次使用时自动下载。有关更多信息，请参阅 [YOLO11 验证文档](https://docs.ultralytics.com/modes/val/)。

# %%
# 下载 COCO val
from ultralytics.utils.downloads import download

download('https://ultralytics.com/assets/coco2017val.zip', unzip=True, dir='datasets')  # 下载（780MB - 5000 张图像）

# %%
# 在 COCO8 val 上验证 YOLO11n
# !yolo val model=yolo11n.pt data=coco8.yaml

# %% [markdown]
# # 3. 训练
#
# <p align=""><a href="https://ultralytics.com/hub"><img width="1000" src="https://github.com/ultralytics/assets/raw/main/yolov8/banner-integrations.png"/></a></p>
#
# 在[检测](https://docs.ultralytics.com/tasks/detect/)、[分割](https://docs.ultralytics.com/tasks/segment/)、[分类](https://docs.ultralytics.com/tasks/classify/)和[姿态](https://docs.ultralytics.com/tasks/pose/)数据集上训练 YOLO11。有关更多信息，请参阅 [YOLO11 训练文档](https://docs.ultralytics.com/modes/train/)。

# %%
#@title 选择 YOLO11 🚀 日志记录器 {run: 'auto'}
logger = 'TensorBoard' #@param ['TensorBoard', 'Weights & Biases']

if logger == 'TensorBoard':
  # !yolo settings tensorboard=True
  # %load_ext tensorboard
  # %tensorboard --logdir .
elif logger == 'Weights & Biases':
  # !yolo settings wandb=True

# %%
# 在 COCO8 上训练 YOLO11n 3 个 epoch
# !yolo train model=yolo11n.pt data=coco8.yaml epochs=3 imgsz=640

# %% [markdown]
# # 4. 导出
#
# 使用 `format` 参数将 YOLO 模型导出为以下任何支持的格式，例如 `format=onnx`。有关更多信息，请参阅[导出文档](https://docs.ultralytics.com/modes/export/)。
#
# - 💡 专业提示：导出为 [ONNX](https://docs.ultralytics.com/integrations/onnx/) 或 [OpenVINO](https://docs.ultralytics.com/integrations/openvino/) 可获得高达 3 倍的 CPU 加速。
# - 💡 专业提示：导出为 [TensorRT](https://docs.ultralytics.com/integrations/tensorrt/) 可获得高达 5 倍的 GPU 加速。
#
# | 格式 | `format` 参数 | 模型 | 元数据 | 参数 |
# |--------|-----------------|-------|----------|------------|
# | [PyTorch](https://pytorch.org/) | - | `yolo11n.pt` | ✅ | - |
# | [TorchScript](https://docs.ultralytics.com/integrations/torchscript) | `torchscript` | `yolo11n.torchscript` | ✅ | `imgsz`, `batch`, `dynamic`, `optimize`, `half`, `nms`, `device` |
# | [ONNX](https://docs.ultralytics.com/integrations/onnx) | `onnx` | `yolo11n.onnx` | ✅ | `imgsz`, `batch`, `dynamic`, `half`, `opset`, `simplify`, `nms`, `device` |
# | [OpenVINO](https://docs.ultralytics.com/integrations/openvino) | `openvino` | `yolo11n_openvino_model/` | ✅ | `imgsz`, `batch`, `dynamic`, `half`, `int8`, `nms`, `fraction`, `device`, `data` |
# | [TensorRT](https://docs.ultralytics.com/integrations/tensorrt) | `engine` | `yolo11n.engine` | ✅ | `imgsz`, `batch`, `dynamic`, `half`, `int8`, `simplify`, `nms`, `fraction`, `device`, `data`, `workspace` |
# | [CoreML](https://docs.ultralytics.com/integrations/coreml) | `coreml` | `yolo11n.mlpackage` | ✅ | `imgsz`, `batch`, `half`, `int8`, `nms`, `device` |

# %%
# !yolo export model=yolo11n.pt format=torchscript

# %% [markdown]
# # 5. Python 用法
#
# YOLO11 使用 Python 优先原则重新设计，提供最无缝的 Python YOLO 体验。YOLO11 模型可以从训练好的检查点加载或从头创建。然后使用方法来训练、验证、预测和导出模型。有关详细的 Python 用法示例，请参阅 [YOLO11 Python 文档](https://docs.ultralytics.com/usage/python/)。

# %%
from ultralytics import YOLO

# 加载模型
model = YOLO('yolo11n.yaml')  # 从头构建新模型
model = YOLO('yolo11n.pt')  # 加载预训练模型（推荐用于训练）

# 使用模型
results = model.train(data='coco8.yaml', epochs=3)  # 训练模型
results = model.val()  # 在验证集上评估模型性能
results = model('https://ultralytics.com/images/bus.jpg')  # 对图像进行预测
results = model.export(format='onnx')  # 将模型导出为 ONNX 格式

# %% [markdown]
# # 6. 任务
#
# YOLO11 可以在视觉 AI 中最常见的任务上进行训练、验证、预测和导出模型：[检测](https://docs.ultralytics.com/tasks/detect/)、[分割](https://docs.ultralytics.com/tasks/segment/)、[分类](https://docs.ultralytics.com/tasks/classify/)和[姿态](https://docs.ultralytics.com/tasks/pose/)。有关更多信息，请参阅 [YOLO11 任务文档](https://docs.ultralytics.com/tasks/)。
#
# <br><img width="1024" src="https://raw.githubusercontent.com/ultralytics/assets/main/im/banner-tasks.png">

# %% [markdown]
# ## 1. 检测
#
# YOLO11 _检测_ 模型没有后缀，是默认的 YOLO11 模型，例如 `yolo11n.pt`，在 COCO 上预训练。有关完整详情，请参阅[检测文档](https://docs.ultralytics.com/tasks/detect/)。

# %%
# 加载 YOLO11n，在 COCO128 上训练 3 个 epoch 并对图像进行预测
from ultralytics import YOLO

model = YOLO('yolo11n.pt')  # 加载预训练的 YOLO 检测模型
model.train(data='coco8.yaml', epochs=3)  # 训练模型
model('https://ultralytics.com/images/bus.jpg')  # 对图像进行预测

# %% [markdown]
# ## 2. 分割
#
# YOLO11 _分割_ 模型使用 `-seg` 后缀，例如 `yolo11n-seg.pt`，在 COCO 上预训练。有关完整详情，请参阅[分割文档](https://docs.ultralytics.com/tasks/segment/)。

# %%
# 加载 YOLO11n-seg，在 COCO128-seg 上训练 3 个 epoch 并对图像进行预测
from ultralytics import YOLO

model = YOLO('yolo11n-seg.pt')  # 加载预训练的 YOLO 分割模型
model.train(data='coco8-seg.yaml', epochs=3)  # 训练模型
model('https://ultralytics.com/images/bus.jpg')  # 对图像进行预测

# %% [markdown]
# ## 3. 分类
#
# YOLO11 _分类_ 模型使用 `-cls` 后缀，例如 `yolo11n-cls.pt`，在 ImageNet 上预训练。有关完整详情，请参阅[分类文档](https://docs.ultralytics.com/tasks/classify/)。

# %%
# 加载 YOLO11n-cls，在 mnist160 上训练 3 个 epoch 并对图像进行预测
from ultralytics import YOLO

model = YOLO('yolo11n-cls.pt')  # 加载预训练的 YOLO 分类模型
model.train(data='mnist160', epochs=3)  # 训练模型
model('https://ultralytics.com/images/bus.jpg')  # 对图像进行预测

# %% [markdown]
# ## 4. 姿态
#
# YOLO11 _姿态_ 模型使用 `-pose` 后缀，例如 `yolo11n-pose.pt`，在 COCO Keypoints 上预训练。有关完整详情，请参阅[姿态文档](https://docs.ultralytics.com/tasks/pose/)。

# %%
# 加载 YOLO11n-pose，在 COCO8-pose 上训练 3 个 epoch 并对图像进行预测
from ultralytics import YOLO

model = YOLO('yolo11n-pose.pt')  # 加载预训练的 YOLO 姿态模型
model.train(data='coco8-pose.yaml', epochs=3)  # 训练模型
model('https://ultralytics.com/images/bus.jpg')  # 对图像进行预测

# %% [markdown]
# ## 5. 旋转边界框（OBB）
#
# YOLO11 _OBB_ 模型使用 `-obb` 后缀，例如 `yolo11n-obb.pt`，在 DOTA 数据集上预训练。有关完整详情，请参阅 [OBB 文档](https://docs.ultralytics.com/tasks/obb/)。

# %%
# 加载 YOLO11n-obb，在 DOTA8 上训练 3 个 epoch 并对图像进行预测
from ultralytics import YOLO

model = YOLO('yolo11n-obb.pt')  # 加载预训练的 YOLO OBB 模型
model.train(data='dota8.yaml', epochs=3)  # 训练模型
model('https://ultralytics.com/images/boats.jpg')  # 对图像进行预测

# %% [markdown]
# # 附录
#
# 以下是附加内容。

# %%
# 从源码 pip 安装
# !uv pip install git+https://github.com/ultralytics/ultralytics@main

# %%
# Git 克隆并在 'main' 分支上运行测试
# !git clone https://github.com/ultralytics/ultralytics -b main
# !uv pip install -qe ultralytics

# %%
# 运行测试（仅限 Git 克隆）
# !pytest ultralytics/tests

# %%
# 验证多个模型
for x in 'nsmlx':
  # !yolo val model=yolo11{x}.pt data=coco.yaml
